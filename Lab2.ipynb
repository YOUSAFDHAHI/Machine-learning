# %%
import pandas as pd

# %%
df = pd.read_csv("simple_customer_churn.csv")

# %%
df.shape
# Out:
# (20, 5)

# %%
df.head()
# Out:
#    CustomerID  Age  MonthlyCharges  TenureMonths Churn
# 0           1   25              70             1   Yes
# 1           2   34              80            12    No
# 2           3   45              90            24    No
# 3           4   23              60             3   Yes
# 4           5   52             100            36    No

# %%
df.dtypes
# Out:
# CustomerID        int64
# Age               int64
# MonthlyCharges    int64
# TenureMonths      int64
# Churn               str
# dtype: object
